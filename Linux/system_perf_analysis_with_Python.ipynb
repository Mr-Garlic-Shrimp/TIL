# %% [markdown]
# # Pythonによるシステムパフォーマンス分析

# %%
import polars as pl
import pandas as pd
import seaborn as sns
import numpy as np
import os
import math
import pyarrow as pa
import pyarrow.parquet as pq
import itertools
from pathlib import Path
from glob import glob
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %% [markdown]
# ## ○ コアごとのCPU使用率データに対する分析
# sar -P ALL（コアごとのCPU使用率）の出力結果が書き込まれたテキストファイルが複数ある。
# これに対して以下を行う。
#
# 1. 前処理
# 2. 可視化

# %%
# テキストファイルのパスを取得
sar_files = glob('./input/*.txt')

# %%
pl.read_csv(sar_files[0])
# Out:
# shape: (75, 1)
# ┌─────────────────────────────────────┐
# │ Linux 5.15.90.1-microsoft-standa... │
# │ ---                                 │
# │ str                                 │
# ╞═════════════════════════════════════╡
# │ 12:49:54        CPU     %user   ... │
# │ 12:49:55        all      0.33   ... │
# │ 12:49:55          0      0.98   ... │
# │ 12:49:55          1      0.00   ... │
# │ ...                                 │
# │ Average:          8      1.11   ... │
# │ Average:          9      0.27   ... │
# │ Average:         10      1.65   ... │
# │ Average:         11      1.10   ... │
# └─────────────────────────────────────┘
